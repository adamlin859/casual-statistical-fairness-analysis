# %%
import networkx as nx
from cdt.causality.graph import PC, LiNGAM, GES, CGNN
from cdt.data import load_dataset
from matplotlib import pyplot as plt

# %%
data, graph = load_dataset("sachs")

# %%
data.head()
# Out:
#    praf  pmek   plcg   PIP2   PIP3  p44/42  pakts473    PKA    PKC   P38  pjnk
# 0  26.4  13.2   8.82  18.30  58.80    6.61      17.0  414.0  17.00  44.9  40.0
# 1  35.9  16.5  12.30  16.80   8.13   18.60      32.5  352.0   3.37  16.5  61.5
# 2  59.4  44.1  14.60  10.20  13.00   14.90      32.5  403.0  11.40  31.9  19.5
# 3  73.0  82.8  23.10  13.50   1.29    5.83      11.8  528.0  13.70  28.6  23.1
# 4  33.7  19.8   5.19   9.73  24.80   21.10      46.1  305.0   4.66  25.7  81.3

# %%
obj = PC()
output = obj.predict(data)

nx.draw_networkx(output, font_size=8)
plt.show()

# %%
obj = LiNGAM()
output = obj.predict(data)

nx.draw_networkx(output, font_size=8)
plt.show()

# %%
obj = GES()
output = obj.predict(data)

nx.draw_networkx(output, font_size=8)
plt.show()

# %%
obj = CGNN()
output = obj.predict(data)

nx.draw_networkx(output, font_size=8)
plt.show()
# Out:
# An exhaustive search of the causal structure of CGNN without skeleton is super-exponential in the number of variables.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/l6fzng_d5t7fzjp5czd95r7w0000gn/T/ipykernel_9779/4120014186.py in <module>
#       1 obj = CGNN()
# ----> 2 output = obj.predict(data)
#       3
#       4 nx.draw_networkx(output, font_size=8)
#       5 plt.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/cdt/causality/graph/model.py in predict(self, df_data, graph, **kwargs)
#      61         """
#      62         if graph is None:
# ---> 63             return self.create_graph_from_data(df_data, **kwargs)
#      64         elif isinstance(graph, nx.DiGraph):
#      65             return self.orient_directed_graph(df_data, graph, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/cdt/causality/graph/CGNN.py in create_graph_from_data(self, data)
#     352             nb_vars = data.__featurelen__()
#     353             names = data.get_names()
# --> 354         candidates = [np.reshape(np.array(i), (nb_vars, nb_vars)) for i in itertools.product([0, 1], repeat=nb_vars*nb_vars)
#     355                       if (np.trace(np.reshape(np.array(i), (nb_vars, nb_vars))) == 0
#     356                           and nx.is_directed_acyclic_graph(nx.DiGraph(np.reshape(np.array(i), (nb_vars, nb_vars)))))]
#
# /opt/anaconda3/lib/python3.8/site-packages/cdt/causality/graph/CGNN.py in <listcomp>(.0)
#     354         candidates = [np.reshape(np.array(i), (nb_vars, nb_vars)) for i in itertools.product([0, 1], repeat=nb_vars*nb_vars)
#     355                       if (np.trace(np.reshape(np.array(i), (nb_vars, nb_vars))) == 0
# --> 356                           and nx.is_directed_acyclic_graph(nx.DiGraph(np.reshape(np.array(i), (nb_vars, nb_vars)))))]
#     357         warnings.warn("A total of {} graphs will be evaluated.".format(len(candidates)))
#     358         scores = [parallel_graph_evaluation(data, i, njobs=self.njobs, nh=self.nh,
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/classes/digraph.py in __init__(self, incoming_graph_data, **attr)
#     317         # attempt to load graph with data
#     318         if incoming_graph_data is not None:
# --> 319             convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     320         # load graph attributes (must be after convert)
#     321         self.graph.update(attr)
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/convert.py in to_networkx_graph(data, create_using, multigraph_input)
#     142         if isinstance(data, (np.matrix, np.ndarray)):
#     143             try:
# --> 144                 return nx.from_numpy_matrix(data, create_using=create_using)
#     145             except Exception as e:
#     146                 raise nx.NetworkXError(
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/convert_matrix.py in from_numpy_matrix(A, parallel_edges, create_using)
#     685         DeprecationWarning,
#     686     )
# --> 687     return from_numpy_array(A, parallel_edges=parallel_edges, create_using=create_using)
#     688
#     689
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/convert_matrix.py in from_numpy_array(A, parallel_edges, create_using)
#    1363
#    1364     # Make sure we get even the isolated nodes of the graph.
# -> 1365     G.add_nodes_from(range(n))
#    1366     # Get a list of all the entries in the array with nonzero entries. These
#    1367     # coordinates become edges in the graph. (convert to int from np.int64)
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/classes/digraph.py in add_nodes_from(self, nodes_for_adding, **attr)
#     473             try:
#     474                 newnode = n not in self._node
# --> 475                 newdict = attr
#     476             except TypeError:
#     477                 n, ndict = n
#
# KeyboardInterrupt:
